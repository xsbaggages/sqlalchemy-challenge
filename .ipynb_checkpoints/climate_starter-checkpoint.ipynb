# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, asc, desc

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
inspector = inspect(engine)
columns = inspector.get_columns('measurement')
for c in columns:
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
engine.execute('select * from measurement').fetchall()
# Out:
# [(1, 'USC00519397', '2010-01-01', 0.08, 65.0),
#  (2, 'USC00519397', '2010-01-02', 0.0, 63.0),
#  (3, 'USC00519397', '2010-01-03', 0.0, 74.0),
#  (4, 'USC00519397', '2010-01-04', 0.0, 76.0),
#  (5, 'USC00519397', '2010-01-06', None, 73.0),
#  (6, 'USC00519397', '2010-01-07', 0.06, 70.0),
#  (7, 'USC00519397', '2010-01-08', 0.0, 64.0),
#  (8, 'USC00519397', '2010-01-09', 0.0, 68.0),
#  (9, 'USC00519397', '2010-01-10', 0.0, 73.0),
#  (10, 'USC00519397', '2010-01-11', 0.01, 64.0),
#  (11, 'USC00519397', '2010-01-12', 0.0, 61.0),
#  (12, 'USC00519397', '2010-01-14', 0.0, 66.0),
#  (13, 'USC00519397', '2010-01-15', 0.0, 65.0),
#  (14, 'USC00519397', '2010-01-16', 0.0, 68.0),
#  (15, 'USC00519397', '2010-01-17', 0.0, 64.0),
#  (16, 'USC00519397', '2010-01-18', 0.0, 72.0),
#  (17, 'USC00519397', '2010-01-19', 0.0, 66.0),
#  (18, 'USC00519397', '2010-01-20', 0.0, 66.0),
#  (19, 'USC00519397', '2010-01-21', 0.0, 69.0),
#  (20, 'USC00519397', '2010-01-22', 0.0, 67.0),
# ...

# %%
columns = inspector.get_columns('station')
for c in columns:
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
engine.execute('select * from station').fetchall()
# Out:
# [(1, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (2, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (3, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (4, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (5, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (6, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (7, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (8, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (9, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4)]

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results
# Finding out the date of the last data point in the database
last_date = session.query(Measurement.date).order_by(Measurement.date.desc()).first()[0]

# execute.engine('select date from measurement')
print(last_date)
# Calculate the date 1 year ago from the last data point in the database
one_year_ago = dt.date(2017,8,23) - dt.timedelta(days=365)
print(one_year_ago)
# Out:
# 2017-08-23
# 2016-08-23

# %%
# Perform a query to retrieve the data and precipitation scores
precip_score = session.query(Measurement.date, Measurement.prcp).\
        filter(Measurement.date >= one_year_ago, Measurement.date <= last_date).order_by(Measurement.date).all()
precip_score
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-23', 0.15),
#  ('2016-08-23', 0.05),
#  ('2016-08-23', None),
#  ('2016-08-23', 0.02),
#  ('2016-08-23', 1.79),
#  ('2016-08-23', 0.7),
#  ('2016-08-24', 0.08),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 2.28),
#  ('2016-08-24', None),
#  ('2016-08-24', 1.22),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 1.45),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.21),
#  ('2016-08-25', 0.06),
#  ('2016-08-25', 0.11),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.03),
#  ('2016-08-26', 0.02),
#  ('2016-08-26', 0.04),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.01),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.18),
#  ('2016-08-27', 0.02),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.12),
#  ('2016-08-27', None),
#  ('2016-08-28', 0.01),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.6),
#  ('2016-08-28', 2.07),
#  ('2016-08-29', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
# Sort the dataframe by date
precip_score_df = pd.DataFrame(data=precip_score)
precip_score_df.head(20)
# Out:
#           date  prcp
# 0   2016-08-23  0.00
# 1   2016-08-23  0.15
# 2   2016-08-23  0.05
# 3   2016-08-23   NaN
# 4   2016-08-23  0.02
# 5   2016-08-23  1.79
# 6   2016-08-23  0.70
# 7   2016-08-24  0.08
# 8   2016-08-24  2.15
# 9   2016-08-24  2.28
# 10  2016-08-24   NaN
# 11  2016-08-24  1.22
# 12  2016-08-24  2.15
# 13  2016-08-24  1.45
# 14  2016-08-25  0.08
# 15  2016-08-25  0.08
# 16  2016-08-25  0.00
# 17  2016-08-25  0.00
# 18  2016-08-25  0.21
# 19  2016-08-25  0.06

# %%
precip_score_df.set_index('date')
# Out:
#             prcp
# date
# 2016-08-23  0.00
# 2016-08-23  0.15
# 2016-08-23  0.05
# 2016-08-23   NaN
# 2016-08-23  0.02
# ...          ...
# 2017-08-22  0.50
# 2017-08-23  0.00
# 2017-08-23  0.00
# 2017-08-23  0.08
# 2017-08-23  0.45
#
# [2230 rows x 1 columns]

# %%
# Use Pandas Plotting with Matplotlib to plot the data
# precip_score_df=pd.DataFrame(data=precip_score)
plt.figure(figsize = (12,10))
plt.plot(precip_score_df['date'], precip_score_df['prcp'])
plt.title("Precipitation in Hawaii")
plt.xlabel('Date')
plt.xticks(['2016-08-23', '2016-09-23', '2016-10-23', '2016-11-23', '2016-12-23', '2017-01-23', '2017-02-23', '2017-03-23', '2017-04-23', '2017-05-23', '2017-06-23', '2017-07-23', '2017-08-23'], rotation='vertical')
plt.ylabel('Rainfall (Inches)')
plt.legend(['Precipitation'])
plt.tight_layout()
plt.show()

# plt.figure(figsize = (12,10))
# precipitation_df.plot()

# %%
# Use Pandas to calculate the summary statistics for the precipitation data
precip_score_df.describe()
# Out:
#               prcp
# count  2021.000000
# mean      0.177279
# std       0.461190
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %%
# Design a query to show how many stations are available in this dataset?
session.query(func.count(Station.station)).all()
# Out:
# [(9)]

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
engine.execute('select station, count(*) from measurement group by station order by count(*) desc').fetchall()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
stats = [func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)]

session.query(*stats).filter(Measurement.station == 'USC00519281').all()
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Choose the station with the highest number of temperature observations.

# Finding out the date of the last data point in the database
lastyear_s = session.query(Measurement.date).filter(Measurement.station == 'USC00519281').order_by(Measurement.date.desc()).first()[0]
lastyear_s
# Out:
# '2017-08-18'

# %%
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
# Calculate the date 1 year ago from the last data point in the database
one_year_ago_s = dt.datetime.strptime(lastyear_s, '%Y-%m-%d') - dt.timedelta(days=365)
print(one_year_ago_s)
# Out:
# 2016-08-18 00:00:00

# %%
station_data = session.query(Measurement.tobs).\
        filter(Measurement.date >= one_year_ago_s, Measurement.date <= lastyear_s, Measurement.station == 'USC00519281' ).order_by(Measurement.date.desc()).all()
# station_data
x = [x[0] for x in station_data]

plt.hist(x, bins = 12)
plt.ylabel('Frequency')
plt.xlabel('Temperature')
plt.legend(['tobs'])
plt.show()

# %% [markdown]
# ## Bonus Challenge Assignment

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
print(calc_temps('2017-03-07', '2017-03-21'))
# Out:
# [(62.0, 71.32608695652173, 82.0)]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
trip_df = pd.DataFrame(calc_temps('2017-03-07', '2017-03-21'), columns=['Min Temp', 'Avg Temp', 'Max Temp'])
avg_temp = trip_df['Avg Temp']
min_max_temp = trip_df.iloc[0]['Max Temp'] - trip_df.iloc[0]['Min Temp']
avg_temp.plot(kind='bar', yerr=min_max_temp, figsize=(6,8), alpha=0.5)
plt.title("Trip Avg Temp", fontsize=20)
plt.ylabel("Temp (F)")
plt.xticks([])
plt.grid()
plt.show()

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
# .join(Expense.cost_center)
start_date = dt.datetime.strptime('2017-03-07', '%Y-%m-%d')
end_date = dt.datetime.strptime('2017-03-21', '%Y-%m-%d')
session.query(Measurement.station, Station.name, Station.latitude, Station.longitude, Station.elevation,\
              func.sum(Measurement.prcp).label('Total_Rainfall'))\
            .filter(Measurement.date >= start_date, Measurement.date <= end_date).group_by(Measurement.station)\
            .order_by(desc('Total_Rainfall')).join(Station, Measurement.station == Station.station).all()
# Out:
# [('USC00513117',
#   'KANEOHE 838.1, HI US',
#   21.4234,
#   -157.8015,
#   14.6,
#   1.1500000000000001),
#  ('USC00519281',
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9,
#   0.98),
#  ('USC00514830',
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0,
#   0.69),
#  ('USC00519523',
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5,
#   0.35),
#  ('USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9, 0.06),
#  ('USC00516128',
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4,
#   0.01),
#  ('USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0, 0.0)]

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`
# Set the start and end date of the trip
# Use the start and end date to create a range of dates
# Strip off the year and save a list of %m-%d strings
# Loop through the list of %m-%d strings and calculate the normals for each date

normals = []
trip_dates = []

start_date = dt.datetime.strptime('2017-03-07', '%Y-%m-%d')
end_date = dt.datetime.strptime('2017-03-21', '%Y-%m-%d')

while start_date <= end_date:
    trip_dates.append(start_date)
    normals.append(daily_normals(dt.datetime.strftime(start_date, '%m-%d')))
    start_date += dt.timedelta(days=1)

normals
# Out:
# [[(60.0, 69.17241379310344, 78.0)],
#  [(59.0, 68.72413793103448, 78.0)],
#  [(57.0, 68.56140350877193, 75.0)],
#  [(57.0, 69.12280701754386, 75.0)],
#  [(60.0, 69.89285714285714, 82.0)],
#  [(62.0, 69.88888888888889, 80.0)],
#  [(56.0, 69.29629629629629, 77.0)],
#  [(62.0, 70.32758620689656, 77.0)],
#  [(58.0, 68.54716981132076, 76.0)],
#  [(60.0, 69.70370370370371, 78.0)],
#  [(57.0, 68.54, 75.0)],
#  [(57.0, 67.7843137254902, 76.0)],
#  [(60.0, 69.1, 75.0)],
#  [(62.0, 70.11764705882354, 80.0)],
#  [(60.0, 71.07692307692308, 77.0)]]

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

dates_df = pd.DataFrame(trip_dates, columns=['Dates'])
normals_df = pd.DataFrame(normals, columns=['Min', 'Ave', 'Max'])
final_df = pd.concat([dates_df, normals_df], axis=1)

final_df.set_index('Dates')
# Out:
#              Min        Ave   Max
# Dates
# 2017-03-07  60.0  69.172414  78.0
# 2017-03-08   NaN        NaN   NaN
# 2017-03-09   NaN        NaN   NaN
# 2017-03-10   NaN        NaN   NaN
# 2017-03-11   NaN        NaN   NaN
# 2017-03-12   NaN        NaN   NaN
# 2017-03-13   NaN        NaN   NaN
# 2017-03-14   NaN        NaN   NaN
# 2017-03-15   NaN        NaN   NaN
# 2017-03-16   NaN        NaN   NaN
# 2017-03-17   NaN        NaN   NaN
# 2017-03-18   NaN        NaN   NaN
# 2017-03-19   NaN        NaN   NaN
# 2017-03-20   NaN        NaN   NaN
# 2017-03-21   NaN        NaN   NaN

# %%
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     496         result = _convert_object_array(
# --> 497             content, columns, dtype=dtype, coerce_float=coerce_float
#     498         )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     580             raise AssertionError(
# --> 581                 f"{len(columns)} columns passed, passed data had "
#     582                 f"{len(content)} columns"
#
# AssertionError: 3 columns passed, passed data had 1 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
# Plot the daily normals as an area plot with `stacked=False`
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-174-ff65424e5174> in <module>
#       1 # Plot the daily normals as an area plot with `stacked=False`
# ----> 2 normals = normals_df.plot.area(stacked=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in area(self, x, y, **kwargs)
#    1361             >>> ax = df.plot.area(x='day')
#    1362         """
# -> 1363         return self(kind="area", x=x, y=y, **kwargs)
#    1364
#    1365     def pie(self, **kwargs):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ...
